5.89671228, 6.00644649, 5.6492383 , 6.32981618, 1.20361093, 0.24920804,
0.95689945, 1.23721014, 1.61277106, 1.55228548, 1.29673586, 1.59115134,
0.59275221, 1.26844306, 1.13310831, 1.54133306, 1.99356869, 2.38680626,
0.35872192, 0.93011196, 1.62580602, 1.55404353, 1.03367456, 1.51202827,
1.37847028, 1.40056109, 1.06159457, 1.85922382, 1.61193188, 1.80933512,
1.41456707, 0.96834546, 1.64760001, 1.34495786, 0.82122207, 0.83697301,
1.56850728, 0.46648891, 1.06468126, 1.01283704, 0.88630071, 1.48962477,
2.0312526 , 1.42475148,10.45443217,10.43788383,10.81228228, 9.80344087,
11.05115455, 9.82748664, 9.52573572,10.57248883, 9.76288663, 7.0986453 ,
9.48177219,11.37940279, 7.82645065, 8.56477161, 7.96057329,11.97919575,
9.45119377, 9.72936111, 9.79917027, 8.41477641, 9.14045113, 7.75633631,
9.76199524, 7.47149297,10.15265034,12.88365358, 7.25328458,10.29892131,
9.62640758, 7.07487864, 7.7298434 , 9.59876942,10.75872478, 9.17389178,
11.86123665, 5.4544396 , 8.17291469, 8.53377478, 9.30638149,10.34991551,
19.50028688,17.95400605,18.32301245,20.56193926,18.15979095,18.00392474,
20.65440952,19.42431434,16.31479815,20.6806226 ,20.18362998,20.00810459,
17.41648735,16.49333307,18.41900611,18.4564177 ,16.67322952,19.73272973,
19.15544991,20.38124342,19.23619298,20.46035918,18.301655 ,19.91085438,
22.28132312,15.88857763,17.55424683,15.94289129,20.0768872 ,21.98010261,
17.87417278,17.49299032,20.54064919,21.08945126,19.38584589,20.60074587,
16.79790306,18.37527665,19.0847149 ,20.05364473],
"class":['Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1',
'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1',
'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1',
'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1',
'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1', 'Group1',
'Group1', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2',
'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2',
'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2',
'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2',
'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2', 'Group2',
'Group2', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3',
'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3',
'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3',
'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3',
'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3', 'Group3',
'Group3', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4',
'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4',
'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4',
'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4',
'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4', 'Group4',
'Group4']}
pd.DataFrame(data).to_csv("data.csv")
#просмотрим данные в виде pandas.DataFrame
pd.DataFrame(data).head(10)
# Out:
#           X         Y   class
# 0  1.853364  6.418501  Group1
# 1  3.375559  6.165670  Group1
# 2  0.504768  5.198381  Group1
# 3  3.288831  4.495180  Group1
# 4  2.473818  6.704767  Group1
# 5  2.317281  6.199844  Group1
# 6  3.113686  6.816048  Group1
# 7  2.386382  6.195176  Group1
# 8  3.844936  5.414930  Group1
# 9  2.031887  5.798185  Group1

# %%
#создаем набор входных данных Х
X = np.c_[data["X"], data["Y"]]

#нормируем входы:
xmin = np.min(X)
Xnorm = (X - xmin) / (np.max(X) - xmin)

#для формирования выходных данных категорий,
#их необходимо закодировать в бинарном виде One-Hot:
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder(sparse_output = False)
Yenc = ohe.fit_transform( np.array(data["class"]).reshape(-1,1) )

#проверка размерностей входных и выходных данных
print(f"Форма тензора X: {Xnorm.shape}")
print(f"Форма тензора Y: {Yenc.shape}")
# Out:
# Форма тензора X: (160, 2)
# Форма тензора Y: (160, 4)

# %%
from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(Xnorm, Yenc, test_size = 0.25)

# %%
print(f"Форма тензора Xtrain: {xTrain.shape}")
print(f"Форма тензора Ytrain: {yTrain.shape}")
print(f"Форма тензора Xtest: {xTest.shape}")
print(f"Форма тензора Ytest: {yTest.shape}")
# Out:
# Форма тензора Xtrain: (120, 2)
# Форма тензора Ytrain: (120, 4)
# Форма тензора Xtest: (40, 2)
# Форма тензора Ytest: (40, 4)

# %%
#построение нейронной сети с помощью Tensorflow
#!pip install keras.models
from keras.models import Sequential
from keras.layers import Dense
model = Sequential( [
Dense( units = 4, activation = "relu", input_shape = (2,) ),
Dense( units = 4, activation = "relu"),
Dense( units = yTrain.shape[1], activation = "sigmoid" )
] )
model.compile( optimizer = "adam", loss = "categorical_crossentropy", metrics = ["categorical_accuracy"] )
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                     │ (None, 4)                   │              12 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 4)                   │              20 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 4)                   │              20 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 52 (208.00 B)
#  Trainable params: 52 (208.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#обучение нейронной сети
hist = model.fit( x = xTrain, y = yTrain, epochs = 80, batch_size = 10 )
import matplotlib.pyplot as plt
plt.plot(hist.history["loss"], label = "Loss")
plt.plot(hist.history["categorical_accuracy"], label = "accuracy")
plt.ylabel("Loss/Accuracy")
plt.xlabel("Epochs")
plt.legend()
plt.show()
# Out:
# Epoch 1/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - categorical_accuracy: 0.5553 - loss: 0.8737
# Epoch 2/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - categorical_accuracy: 0.5217 - loss: 0.8560
# Epoch 3/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - categorical_accuracy: 0.5222 - loss: 0.8670
# Epoch 4/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - categorical_accuracy: 0.5903 - loss: 0.8507
# Epoch 5/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - categorical_accuracy: 0.5468 - loss: 0.8661
# Epoch 6/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - categorical_accuracy: 0.5637 - loss: 0.8726
# Epoch 7/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - categorical_accuracy: 0.5757 - loss: 0.8169
# Epoch 8/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - categorical_accuracy: 0.5120 - loss: 0.8708
# Epoch 9/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - categorical_accuracy: 0.5033 - loss: 0.8534
# Epoch 10/80
# ...

# %%
#оценка модели на тестовой выборке
model.evaluate(xTest, yTest)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - categorical_accuracy: 0.7229 - loss: 0.7137
# [0.7022935152053833, 0.7250000238418579]

# %%
#пройдем каждый пример тестовой выборки отдельно:
match = 0
for i in range(len(xTest)):
  x = xTest[i]
  y = yTest[i]
  #для подачи вектора на вход нейросети, его необходимо преобразовать к
  #двумерному тензору формата (1 строка, n столбцов)
  yPred = model.predict( x.reshape(1,-1) )
  # на выходе yPred также представляет собой двумерный объект
  # из одной строки - вектора логитов - выходов сигмоид (можно посмотреть print(yPred))
  # нам нужно выбрать максимальный из них
  maxLogit = np.argmax(yPred)
  # этот индекс - номер группы объекта, но точно лучше узнать в нашем
  # OneHotEncoder'е - без обратного преоразования можно их посмотреть в массиве categories_
  # номера соответствуют порядку категорий в нем
  # фактическое значение категории (на самом деле которое нам известно - из тестовой выборки)
  yAct = np.argmax(y)
  if maxLogit == yAct:
    match += 1
  print(f"Распознали как группу {ohe.categories_[0][maxLogit]} на самом деле: {ohe.categories_[0][yAct]}" )
print(f"Верно распознано {match} из {len(xTest)}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# Распознали как группу Group4 на самом деле: Group4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Распознали как группу Group3 на самом деле: Group3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Распознали как группу Group4 на самом деле: Group4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Распознали как группу Group2 на самом деле: Group2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Распознали как группу Group3 на самом деле: Group3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Распознали как группу Group3 на самом деле: Group3
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Распознали как группу Group2 на самом деле: Group2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Распознали как группу Group4 на самом деле: Group4
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Распознали как группу Group2 на самом деле: Group2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Распознали как группу Group2 на самом деле: Group2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ...
